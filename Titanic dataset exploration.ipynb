# %%
# importing pandas library

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d=pd.read_excel('/home/soniya/Documents/data.xcel.xlsx')

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Code for seeing top 5 rows in the datset
d.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Find Missing Values using  isNuLL() in following columns - - age , Embarked ,Cabin
d.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
d['Age'].isna().sum()
# Out:
# 177

# %%
d['Embarked'].isna().sum()
# Out:
# 2

# %%
d['Cabin'].isna().sum()
# Out:
# 687

# %%
#calculate the average age of passengers
d['Age'].mean()
# Out:
# 29.69911764705882

# %%
#Visualize the age of  passengers as bar chart ( age V/s count)
sns.countplot(x='Age',data=d)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Bar Plot of  Traveling Alone vs. With Family

d['Alone']=[1 if x==0 else 0 for x in d['Parch']]
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Alone
# 0        0         A/5 21171   7.2500   NaN        S      1
# 1        0          PC 17599  71.2833   C85        C      1
# 2        0  STON/O2. 3101282   7.9250   NaN        S      1
# 3        0            113803  53.1000  C123        S      1
# 4        0            373450   8.0500   NaN        S      1
# ..     ...               ...      ...   ...      ...    ...
# 886      0            211536  13.0000   NaN        S      1
# 887      0            112053  30.0000   B42        S      1
# 888      2        W./C. 6607  23.4500   NaN        S      0
# 889      0            111369  30.0000  C148        C      1
# 890      0            370376   7.7500   NaN        Q      1
#
# [891 rows x 13 columns]

# %%
d['Alone']=[1 if x==0 else 0 for x in d['SibSp']]
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Alone
# 0        0         A/5 21171   7.2500   NaN        S      0
# 1        0          PC 17599  71.2833   C85        C      0
# 2        0  STON/O2. 3101282   7.9250   NaN        S      1
# 3        0            113803  53.1000  C123        S      0
# 4        0            373450   8.0500   NaN        S      1
# ..     ...               ...      ...   ...      ...    ...
# 886      0            211536  13.0000   NaN        S      1
# 887      0            112053  30.0000   B42        S      1
# 888      2        W./C. 6607  23.4500   NaN        S      0
# 889      0            111369  30.0000  C148        C      1
# 890      0            370376   7.7500   NaN        Q      1
#
# [891 rows x 13 columns]

# %%
sns.barplot(d['Parch'],d['Alone'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Parch', ylabel='Alone'>

# %%
#Fill the missing values (with mean values) using fillna - in following columns  - age , Embarked ,Cabin

d['Age'].fillna(d['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  Alone
# 0        0         A/5 21171   7.2500  B96 B98        S      0
# 1        0          PC 17599  71.2833      C85        C      0
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S      1
# 3        0            113803  53.1000     C123        S      0
# 4        0            373450   8.0500  B96 B98        S      1
# ..     ...               ...      ...      ...      ...    ...
# 886      0            211536  13.0000  B96 B98        S      1
# 887      0            112053  30.0000      B42        S      1
# 888      2        W./C. 6607  23.4500  B96 B98        S      0
# 889      0            111369  30.0000     C148        C      1
# 890      0            370376   7.7500  B96 B98        Q      1
#
# [891 rows x 13 columns]

# %%
d['Embarked'].fillna(d['Embarked'].mode())
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  Alone
# 0        0         A/5 21171   7.2500  B96 B98        S      0
# 1        0          PC 17599  71.2833      C85        C      0
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S      1
# 3        0            113803  53.1000     C123        S      0
# 4        0            373450   8.0500  B96 B98        S      1
# ..     ...               ...      ...      ...      ...    ...
# 886      0            211536  13.0000  B96 B98        S      1
# 887      0            112053  30.0000      B42        S      1
# 888      2        W./C. 6607  23.4500  B96 B98        S      0
# 889      0            111369  30.0000     C148        C      1
# 890      0            370376   7.7500  B96 B98        Q      1
#
# [891 rows x 13 columns]

# %%
# Line Plot the  Age wise count of both Survived Population and Deceased Population
sns.lineplot(d['Age'],d['Survived'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
d['Died']=[1 if x==0 else 0 for x in d['Survived']]
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  Alone  Died
# 0        0         A/5 21171   7.2500  B96 B98        S      0     1
# 1        0          PC 17599  71.2833      C85        C      0     0
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S      1     0
# 3        0            113803  53.1000     C123        S      0     0
# 4        0            373450   8.0500  B96 B98        S      1     1
# ..     ...               ...      ...      ...      ...    ...   ...
# 886      0            211536  13.0000  B96 B98        S      1     1
# 887      0            112053  30.0000      B42        S      1     0
# 888      2        W./C. 6607  23.4500  B96 B98        S      0     1
# 889      0            111369  30.0000     C148        C      1     0
# 890      0            370376   7.7500  B96 B98        Q      1     1
#
# [891 rows x 14 columns]

# %%
sns.lineplot(d['Age'],d['Survived'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
#Line Plot the  Fare wise count of both Survived Population and Deceased Population
sns.lineplot(d['Fare'],d['Survived'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare', ylabel='Survived'>

# %%
sns.lineplot(d['Fare'],d['Died'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare', ylabel='Died'>

# %%
#Bar plot of Passenger Class of  Survived Population
sns.barplot(d['Pclass'],d['Survived'])
# Out:
# /home/soniya/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
#Bar plot of Gender Variable 
sns.countplot(x='Sex',data=d)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#filling the values for cabin
d["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# dtype: object

# %%
x=['Cabin']
d.apply(lambda x: x.fillna(x.value_counts().index[0]))
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  24.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  Alone
# 0        0         A/5 21171   7.2500  B96 B98        S      0
# 1        0          PC 17599  71.2833      C85        C      0
# 2        0  STON/O2. 3101282   7.9250  B96 B98        S      1
# 3        0            113803  53.1000     C123        S      0
# 4        0            373450   8.0500  B96 B98        S      1
# ..     ...               ...      ...      ...      ...    ...
# 886      0            211536  13.0000  B96 B98        S      1
# 887      0            112053  30.0000      B42        S      1
# 888      2        W./C. 6607  23.4500  B96 B98        S      0
# 889      0            111369  30.0000     C148        C      1
# 890      0            370376   7.7500  B96 B98        Q      1
#
# [891 rows x 13 columns]
